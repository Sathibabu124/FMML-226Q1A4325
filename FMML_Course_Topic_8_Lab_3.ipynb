# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathibabu124/FMML-226Q1A4325/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-17 15:05:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   123MB/s    in 0.6s
#
# 2024-04-17 15:05:16 (123 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15264   0711.3605v1  We discuss the characteristics and behaviour o...    cs
# 4031    1204.1277v1  In this paper, we present a novel approach for...    cs
# 22913  1710.09443v2  We introduce the Givens Transform, a novel tra...  stat
# 6044   1606.04988v2  We create a new online reduction of multiclass...  stat
# 5603    1309.6830v1  In this paper we propose a multi-armed bandit ...    cs
# ...             ...                                                ...   ...
# 28852  1707.09074v1  Discriminative clustering has been successfull...    cs
# 5493    1109.5311v1  Bias - variance decomposition of the expected ...    cs
# 32899  1511.00048v1  Given a multi-armed bandit problem it may be d...    cs
# 12334  1711.11423v1  The rise of digital and mobile communications ...  stat
# 11878  1703.02721v1  We provide new approximation guarantees for gr...  stat
#
#                                                    title  year  \
# 15264               Very strict selectional restrictions  2007
# 4031           Mouse Simulation Using Two Coloured Tapes  2012
# 22913  General Bayesian Inference over the Stiefel Ma...  2017
# 6044                   Logarithmic Time One-Against-Some  2016
# 5603   Building Bridges: Viewing Active Learning from...  2013
# ...                                                  ...   ...
# 28852  Learning from Video and Text via Large-Scale D...  2017
# 5493   Bias Plus Variance Decomposition for Survival ...  2011
# 32899             The Pareto Regret Frontier for Bandits  2015
# 12334  On reducing the communication cost of the diff...  2017
# 11878  On Approximation Guarantees for Greedy Low Ran...  2017
#
#                                                 keywords
# 15264  [characteristics, behaviour, languages, portug...
# 4031   [interaction, technology, segmentation, recogn...
# 22913  [introduce, transform, transform, orthonormal,...
# 6044   [reduction, multiclass, classification, classi...
# 5603   [algorithm, classification, carefully, constru...
# ...                                                  ...
# 28852  [discriminative, clustering, successfully, sup...
# 5493   [decomposition, regression, classification, im...
# 32899  [desirable, unbalanced, guarantees, specifical...
# 12334  [communications, connected, networked, resulti...
# 11878  [approximation, guarantees, estimation, assump...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15264    [characteristics, behaviour, languages, portug...
# 4031     [interaction, technology, segmentation, recogn...
# 22913    [introduce, transform, transform, orthonormal,...
# 6044     [reduction, multiclass, classification, classi...
# 5603     [algorithm, classification, carefully, constru...
#                                ...
# 8132     [classification, performance, dimensional, str...
# 13210    [breakthrough, compressed, established, dimens...
# 11302    [framework, clustering, functional, introduce,...
# 12441    [uncertainty, quantification, algorithms, appr...
# 1564     [reinforcement, significant, potential, optimi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8820 words.
# Out of those 4604 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="79c6aa63-8f2c-441d-9972-7eb4b0b97cbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79c6aa63-8f2c-441d-9972-7eb4b0b97cbc")) {                    Plotly.newPlot(                        "79c6aa63-8f2c-441d-9972-7eb4b0b97cbc",                        [{"x":["characteristics","constructions","complement","instrument","restrictions","distribution","restricted","reductions","languages","essential","behaviour","definition","selection","portuguese","independent","interface","recognition","interaction","developed","technology","segmentation","applications","intuitive","estimation","simulation","dimensional","everything","containing","algorithms","reduction","algorithm","previously","variational","intractable","constraints","technical","unconstrained","constrained","transform","orthonormal","agnostically","parameters","exponential","dimensionality","probabilistic","approaches","framework","correlation","canonical","illustrate","introduce","factorizations","treatment","modification","inference","application","improvements","statistical","techniques","multiclass","classification","logarithmic","logarithmically","translate","substantially","predictive","performance","prediction","literature","comparisons","experimental","carefully","sequential","constructing","concordant","regularization","confidence","demonstrate","theoretical","generalized","collection","following","dirichlet","practical","significant","allocation","methodology","analyzing","conditions","successes","challenge","confronted","furthermore","appropriately","decomposition","popularity","extension","attention","regression","increasing","considered","predictors","ensembles","illustrated","conditional","oscillates","strategies","associated","successfully","iteration","prospective","alternative","objective","administration","conclusion","computational","stochastic","describes","potential","optimization","evaluated","protocols","experiments","currently","formulated","efficient","processes","uncertainty","promising","computing","particularly","validation","underlying","individual","reinforcement","variability","minimization","structures","grassmannian","approximation","identification","processing","drawbacks","established","initialization","forecasting","simulated","robustness","manifolds","structured","factorization","knowledge","annotated","normalizer","accessible","community","available","addressed","identifier","exclusive","frequency","characterizing","exclusivity","experiment","interpretability","differential","leverages","documents","interpretable","estimates","different","description","summaries","collections","randomized","correspond","structure","summarize","convolution","professional","organized","hierarchical","effective","interpreted","categories","parallelized","hamiltonian","participants","themselves","bilateral","influence","procedures","dissertation","agreement","hierarchy","organisations","consideration","analysing","regulatory","motivated"],"y":[90,9,21,3,15,221,49,12,102,61,34,36,146,4,133,34,364,66,216,58,230,425,26,226,79,181,3,56,598,103,818,115,50,35,147,34,22,54,58,4,1,254,48,57,153,437,557,75,17,75,352,2,28,22,211,241,113,168,374,8,512,23,3,16,44,52,902,224,125,33,369,27,68,48,1,84,49,553,130,60,74,77,26,110,239,23,78,57,126,10,169,3,173,11,66,17,67,177,95,96,141,10,17,13,93,0,91,96,88,46,1,104,159,0,19,289,124,75,131,306,142,11,633,57,43,388,82,70,113,124,75,54,122,117,127,29,61,114,4,82,97,269,12,60,25,20,70,101,12,111,43,381,71,2,15,80,304,32,4,3,54,22,2,89,20,28,37,75,33,62,751,64,14,27,27,32,333,16,45,10,17,105,269,31,60,9,4,14,17,4,56,33,1,22,35,2,30,9,3,56],"type":"bar"},{"x":["characteristics","constructions","complement","instrument","rest ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4604,), (4604, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8291666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>to</span> <span style=''>Offline</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Conversions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Universality</span> <span style=''>and</span> <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Minibatch</span> <span style=''>Sizes</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>towards</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>that</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>converts</span> <span style=''>online</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>into</span> <span style=''>offline</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>the</span> <span style=''>offline</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>setting</span> <span style=''>our</span> <span style=''>derived</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>favourable</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.33689839572192526);'>guarantees</span> <span style=''>which</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>harmonic</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>the</span> <span style=''>queried</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>We</span> <span style=''>further</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objectives</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>smooth</span> <span style=''>case</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.43452380952380953);'>convergence</span> <span style=''>rates</span> <span style=''>are</span> <span style=''>ensured</span> <span style=''>without</span> <span style=''>any</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.42696629213483156);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothness</span> <span style='background-color:rgba(255, 0, 0, 0.3468208092485549);'>parameter</span> <span style=''>while</span> <span style=''>still</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style='background-color:rgba(255, 0, 0, 0.33689839572192526);'>guarantees</span> <span style=''>in</span> <span style=''>the</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>setting</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3980582524271844);'>stochastic</span> <span style=''>setting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>a</span> <span style=''>lazy</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>Without</span> <span style=''>Pixel</span> <span style=''>Wise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reconstruction</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>(VAEs)</span> <span style=''>that</span> <span style=''>are</span> <span style=''>built</span> <span style=''>upon</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>Most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>work</span> <span style=''>towards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>mainly</span> <span style=''>on</span> <span style=''>making</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>flexible</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>leading</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tremendous</span> <span style=''>progress</span> <span style=''>However</span> <span style=''>there</span> <span style=''>have</span> <span style=''>been</span> <span style=''>limited</span> <span style=''>efforts</span> <span style=''>to</span> <span style=''>replace</span> <span style=''>pixel</span> <span style=''>wise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>which</span> <span style=''>have</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>shortcomings</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>use</span> <span style=''>real</span> <span style=''>valued</span> <span style=''>non</span> <span style=''>volume</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>(real</span> <span style=''>NVP)</span> <span style=''>to</span> <span style=''>exactly</span> <span style=''>compute</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>given</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>VAE</span> <span style=''>with</span> <span style=''>this</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complicated</span> <span style=''>VAE</span> <span style='background-color:rgba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Existence</span> <span style=''>of</span> <span style=''>Kernel</span> <span style=''>Function</span> <span style=''>for</span> <span style=''>Kernel</span> <span style=''>Trick</span> <span style=''>of</span> <span style=''>k</span> <span style=''>Means</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>corrects</span> <span style=''>the</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Theorem</span> <span style=''>2</span> <span style=''>from</span> <span style=''>the</span> <span style=''>Gowers</span> <span style=''>paper</span> <span style=''>citepage</span> <span style=''>5Gower1982</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correction</span> <span style=''>is</span> <span style=''>needed</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.36690647482014394);'>establish</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>used</span> <span style=''>commonly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>trick</span> <span style=''>eg</span> <span style=''>for</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style=''>the</span> <span style=''>grounds</span> <span style=''>of</span> <span style=''>distance</span> <span style=''>matrix</span> <span style=''>The</span> <span style=''>scope</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correction</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explained</span> <span style=''>in</span> <span style=''>section</span> <span style=''>2</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bandit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>for</span> <span style=''>Neural</span> <span style=''>Sequence</span> <span style=''>to</span> <span style=''>Sequence</span> <span style=''>Learning</span> <br/><br/><span style=''>Bandit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>where</span> <span style=''>learning</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>from</span> <span style=''>partial</span> <span style=''>feedback</span> <span style=''>This</span> <span style=''>feedback</span> <span style=''>is</span> <span style=''>received</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>task</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>without</span> <span style=''>having</span> <span style=''>access</span> <span style=''>to</span> <span style=''>gold</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>We</span> <span style=''>advance</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>by</span> <span style=''>lifting</span> <span style=''>linear</span> <span style=''>bandit</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>neural</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>control</span> <span style=''>variates</span> <span style=''>into</span> <span style=''>our</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>and</span> <span style=''>improved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>on</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>machine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>translation</span> <span style=''>task</span> <span style=''>that</span> <span style=''>shows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>of</span> <span style=''>up</span> <span style=''>to</span> <span style=''>589</span> <span style=''>BLEU</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09559613319011816)
# 	challenging (0.09631220909416398)
# 	knowledge (0.1364124597207304)
# 	architecture (0.09237379162191192)
# 	segmentation (0.08234872896527032)
# 	information (0.24633011099176513)
# 	different (0.2688865019692087)
# 	detection (0.13498030791263874)
# 	recognition (0.13032581453634084)
# 	convolutional (0.14500537056928034)
#
# Some Statistics words are:
# 	variational (0.10612855007473841)
# 	statistical (0.15296462381664175)
# 	distribution (0.1768809167912307)
# 	algorithm (0.39162929745889385)
# 	stochastic (0.14349775784753363)
# 	estimation (0.18385650224215247)
# 	theoretical (0.1619332336821126)
# 	inference (0.1998006975585451)
# 	regression (0.17339312406576982)
# 	dimensional (0.20528151469855505)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5babfd9b-f157-4780-8140-04c60f7a03b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5babfd9b-f157-4780-8140-04c60f7a03b3")) {                    Plotly.newPlot(                        "5babfd9b-f157-4780-8140-04c60f7a03b3",                        [{"x":["characteristics","constructions","complement","instrument","restrictions","distribution","restricted","reductions","languages","essential","behaviour","definition","selection","portuguese","independent","interface","recognition","interaction","developed","technology","segmentation","applications","intuitive","estimation","simulation","dimensional","everything","containing","algorithms","reduction","algorithm","previously","variational","intractable","constraints","technical","unconstrained","constrained","transform","orthonormal","agnostically","parameters","exponential","dimensionality","probabilistic","approaches","framework","correlation","canonical","illustrate","introduce","factorizations","treatment","modification","inference","application","improvements","statistical","techniques","multiclass","classification","logarithmic","logarithmically","translate","substantially","predictive","performance","prediction","literature","comparisons","experimental","carefully","sequential","constructing","concordant","regularization","confidence","demonstrate","theoretical","generalized","collection","following","dirichlet","practical","significant","allocation","methodology","analyzing","conditions","successes","challenge","confronted","furthermore","appropriately","decomposition","popularity","extension","attention","regression","increasing","considered","predictors","ensembles","illustrated","conditional","oscillates","strategies","associated","successfully","iteration","prospective","alternative","objective","administration","conclusion","computational","stochastic","describes","potential","optimization","evaluated","protocols","experiments","currently","formulated","efficient","processes","uncertainty","promising","computing","particularly","validation","underlying","individual","reinforcement","variability","minimization","structures","grassmannian","approximation","identification","processing","drawbacks","established","initialization","forecasting","simulated","robustness","manifolds","structured","factorization","knowledge","annotated","normalizer","accessible","community","available","addressed","identifier","exclusive","frequency","characterizing","exclusivity","experiment","interpretability","differential","leverages","documents","interpretable","estimates","different","description","summaries","collections","randomized","correspond","structure","summarize","convolution","professional","organized","hierarchical","effective","interpreted","categories","parallelized","hamiltonian","participants","themselves","bilateral","influence","procedures","dissertation","agreement","hierarchy","organisations","consideration","analysing","regulatory","motivated","governing","institutions","institutional","fulfilling","international","understanding","respecting","contracts","governments","backpropagation","presented","demonstrated","including","importance","comparable","significantly","advantage","refinement","expensive","empirical","multilayer","explained","molecular","boltzmann","observation","emphsparse","dependencies","published","typically","resulting","activation","regularizer","invariant","handwritten","connections","permutation","encourages","possibilities","variables","unobserved","connecting","complexity","correlates","distributions","detecting","correlated","encouraging","dependences","phenotype","foundation","outperforms","exploiting","parameter","representative","co ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	oscillates
# 	administration
# 	emphsparse
# 	exemplifies
# 	internally
# 	bhattacharyya
# 	cubically
# 	quadrature
# 	homogeneity
# 	supermodular
# 	censoring
# 	parametrically
# 	perturbing
# 	underestimates
# 	autoencoding
# 	smoothers
# 	normality
# 	accommodates
# 	subgradient
# 	characterise
# Some words which never appear in Statistics papers:
# 	organisations
# 	respecting
# 	governments
# 	manipulative
# 	enrichment
# 	searchers
# 	absorption
# 	occlusions
# 	disjunctions
# 	possibilistic
# 	disjunctive
# 	photometric
# 	altogether
# 	impairments
# 	comprehend
# 	covariant
# 	abstractions
# 	formalisms
# 	inheritance
# 	abductive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.07370750599373e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667
